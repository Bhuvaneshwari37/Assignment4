# %%
# importing Libraries
import pandas as pd
import numpy as np
import pickle
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder

# %%
data = pd.read_csv('/content/swiggy.csv')

# %%
data.head()
# Out:
#        id               name    city rating     rating_count   cost  \
# 0  567335     AB FOODS POINT  Abohar     --  Too Few Ratings  ₹ 200
# 1  531342  Janta Sweet House  Abohar    4.4      50+ ratings  ₹ 200
# 2  158203  theka coffee desi  Abohar    3.8     100+ ratings  ₹ 100
# 3  187912          Singh Hut  Abohar    3.7      20+ ratings  ₹ 250
# 4  543530      GRILL MASTERS  Abohar     --  Too Few Ratings  ₹ 250
#
#                       cuisine          lic_no  \
# 0            Beverages,Pizzas  22122652000138
# 1               Sweets,Bakery  12117201000112
# 2                   Beverages  22121652000190
# 3            Fast Food,Indian  22119652000167
# 4  Italian-American,Fast Food  12122201000053
#
#                                                 link  \
# 0  https://www.swiggy.com/restaurants/ab-foods-po...
# 1  https://www.swiggy.com/restaurants/janta-sweet...
# 2  https://www.swiggy.com/restaurants/theka-coffe...
# 3  https://www.swiggy.com/restaurants/singh-hut-n...
# 4  https://www.swiggy.com/restaurants/grill-maste...
#
#                                              address              menu
# 0  AB FOODS POINT, NEAR RISHI NARANG DENTAL CLINI...  Menu/567335.json
# 1  Janta Sweet House, Bazar No.9, Circullar Road,...  Menu/531342.json
# 2         theka coffee desi, sahtiya sadan road city  Menu/158203.json
# 3    Singh Hut, CIRCULAR ROAD NEAR NEHRU PARK ABOHAR  Menu/187912.json
# 4  GRILL MASTERS, ADA Heights, Abohar - Hanumanga...  Menu/543530.json

# %%
# checking no_of_rows and columns
data.shape
# Out:
# (148541, 11)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148541 entries, 0 to 148540
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            148541 non-null  int64
#  1   name          148455 non-null  object
#  2   city          148541 non-null  object
#  3   rating        148455 non-null  object
#  4   rating_count  148455 non-null  object
#  5   cost          148410 non-null  object
#  6   cuisine       148442 non-null  object
#  7   lic_no        148312 non-null  object
#  8   link          148541 non-null  object
#  9   address       148455 non-null  object
#  10  menu          148541 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 12.5+ MB

# %%
# checking duplicates rows in DataFrame
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.isnull().sum()
# Out:
# id                0
# name             86
# city              0
# rating           86
# rating_count     86
# cost            131
# cuisine          99
# lic_no          229
# link              0
# address          86
# menu              0
# dtype: int64

# %%
data.fillna(0,inplace=True)

# %%
data.isnull().sum()
# Out:
# id              0
# name            0
# city            0
# rating          0
# rating_count    0
# cost            0
# cuisine         0
# lic_no          0
# link            0
# address         0
# menu            0
# dtype: int64

# %%
data.columns
# Out:
# Index(['id', 'name', 'city', 'rating', 'rating_count', 'cost', 'cuisine',
#        'lic_no', 'link', 'address', 'menu'],
#       dtype='object')

# %%
Swiggy_data = data.head(25000).copy()

# %%
Swiggy_data.shape
# Out:
# (25000, 11)

# %%
Swiggy_data.isnull().sum()
# Out:
# id              0
# name            0
# city            0
# rating          0
# rating_count    0
# cost            0
# cuisine         0
# lic_no          0
# link            0
# address         0
# menu            0
# dtype: int64

# %%
# checking all the unique values of cusines column
Swiggy_data['cuisine'].unique()
# Out:
# array(['Beverages,Pizzas', 'Sweets,Bakery', 'Beverages', ...,
#        'Sweets,Italian', 'Indian,Italian-American', 'Pastas,North Indian'],
#       dtype=object)

# %%
Swiggy_data['cuisine'].isnull().sum()
# Out:
# np.int64(0)

# %%
Swiggy_data['city'].unique()
# Out:
# array(['Abohar', 'Adilabad', 'Adityapur', 'Adoni', 'Agartala', 'Agra',
#        'Vastrapur,Ahmedabad', 'GOTA,Ahmedabad',
#        'Paldi & Ambawadi,Ahmedabad', 'Ghatlodia,Ahmedabad',
#        'Bopal,Ahmedabad', 'Gandhinagar,Ahmedabad', 'LalDarwaja,Ahmedabad',
#        'Naranpura,Ahmedabad', 'Navrangpura,Ahmedabad',
#        'Science City,Ahmedabad', 'Maninagar,Ahmedabad',
#        'Chandkheda,Ahmedabad', 'Ahmednagar', 'Aizawl', 'Ajmer', 'Akola',
#        'Alappuzha', 'Aligarh', 'Alipurduar', 'Allahabad', 'Alwar',
#        'Ambala', 'Ambikapur', 'Ambur', 'Amravati', 'Amreli', 'Amritsar',
#        'Anand', 'Anantapur', 'Ankleshwar', 'Arakkonam', 'Arambagh',
#        'Arrah', 'Aruppukottai', 'Asansol', 'Aurangabad',
#        'Aurangabad_bihar', 'Azamgarh', 'Baddi', 'Bagalkot', 'Bagdogra',
#        'Bahadurgarh', 'Bahraich', 'Balaghat', 'Balangir', 'Balasore',
#        'Ballari', 'Balrampur', 'Balurghat', 'Banda',
#        'Yeshwanthpur,Bangalore', 'Geddalahalli,Bangalore',
#        'Koramangala,Bangalore', 'JP Nagar,Bangalore',
#        'Mahadevpura,Bangalore', 'HSR,Bangalore', 'Arekere,Bangalore',
#        'Indiranagar,Bangalore', 'Banashankari,Bangalore',
#        'Whitefield,Bangalore', 'Nagavara & Hennur,Bangalore',
#        'Kammanahalli/Kalyan Nagar,Bangalore',
#        'Kumaraswamy Layout & Uttarahalli,Bangalore', 'BTM,Bangalore',
#        'Battarahalli,Bangalore', 'Basaveshwaranagar,Bangalore',
#        'Frazer Town,Bangalore', 'Sanjay Nagar, New BEL Road,Bangalore',
#        'Yelahanka,Bangalore', 'Majestic,Bangalore',
#        'Kanakapura Road,Bangalore', 'R.T. Nagar,Bangalore',
#        'Kadugodi,Bangalore', 'Marathahalli,Bangalore',
#        'Rajarajeshwari Nagar,Bangalore', 'CV Raman Nagar,Bangalore',
#        'Electronic City,Bangalore', 'Rajajinagar,Bangalore',
#        'Kadubeesanahalli,Bangalore', 'Shantinagar,Bangalore',
#        'Jayanagar,Bangalore', 'Central Bangalore,Bangalore', 'Bantwal',
#        'Bapatlachirala', 'Baramati', 'Baran', 'Bardhaman', 'Bardoli',
#        'Bareilly', 'Barmer', 'Barnala', 'Barshi', 'Barwani', 'Basirhat',
#        'Basti', 'Batala', 'Bathinda', 'Beawar', 'Beed', 'Begusarai',
#        'Bela-pratapgarh', 'Belgaum'], dtype=object)

# %%
def split_city(value):
    parts = value.split(',')
    if len(parts) == 1:
        return pd.Series([value.strip(), 'General'])
    else:
        return pd.Series([parts[-1].strip(), ','.join(parts[:-1]).strip()])

# %%
Swiggy_data.head()
# Out:
#        id               name    city rating     rating_count   cost  \
# 0  567335     AB FOODS POINT  Abohar     --  Too Few Ratings  ₹ 200
# 1  531342  Janta Sweet House  Abohar    4.4      50+ ratings  ₹ 200
# 2  158203  theka coffee desi  Abohar    3.8     100+ ratings  ₹ 100
# 3  187912          Singh Hut  Abohar    3.7      20+ ratings  ₹ 250
# 4  543530      GRILL MASTERS  Abohar     --  Too Few Ratings  ₹ 250
#
#                       cuisine          lic_no  \
# 0            Beverages,Pizzas  22122652000138
# 1               Sweets,Bakery  12117201000112
# 2                   Beverages  22121652000190
# 3            Fast Food,Indian  22119652000167
# 4  Italian-American,Fast Food  12122201000053
#
#                                                 link  \
# 0  https://www.swiggy.com/restaurants/ab-foods-po...
# 1  https://www.swiggy.com/restaurants/janta-sweet...
# 2  https://www.swiggy.com/restaurants/theka-coffe...
# 3  https://www.swiggy.com/restaurants/singh-hut-n...
# 4  https://www.swiggy.com/restaurants/grill-maste...
#
#                                              address              menu
# 0  AB FOODS POINT, NEAR RISHI NARANG DENTAL CLINI...  Menu/567335.json
# 1  Janta Sweet House, Bazar No.9, Circullar Road,...  Menu/531342.json
# 2         theka coffee desi, sahtiya sadan road city  Menu/158203.json
# 3    Singh Hut, CIRCULAR ROAD NEAR NEHRU PARK ABOHAR  Menu/187912.json
# 4  GRILL MASTERS, ADA Heights, Abohar - Hanumanga...  Menu/543530.json

# %%
Swiggy_data[['city_names','location']] = Swiggy_data['city'].apply(split_city)

# %%
columns_to_be_dropped = ['city','lic_no','link', 'address','menu' ]

# %%
Swiggy_data.drop(columns=columns_to_be_dropped,inplace=True)

# %%
Swiggy_data.head(20)
# Out:
#         id                                     name rating     rating_count  \
# 0   567335                           AB FOODS POINT     --  Too Few Ratings
# 1   531342                        Janta Sweet House    4.4      50+ ratings
# 2   158203                        theka coffee desi    3.8     100+ ratings
# 3   187912                                Singh Hut    3.7      20+ ratings
# 4   543530                            GRILL MASTERS     --  Too Few Ratings
# 5   158204                                Sam Uncle    3.6      20+ ratings
# 6   156588                         shere punjab veg    4.0     100+ ratings
# 7   244866                Shri Balaji Vaishno Dhaba     --  Too Few Ratings
# 8   156602                 Hinglaj Kachori Bhandhar    4.2      20+ ratings
# 9   158193                                yummy hub     --  Too Few Ratings
# 10  407249             CHAWLA SAAB THE JUICE MASTER     --  Too Few Ratings
# 11  156590                         Sethi Milk Badam    4.2      20+ ratings
# 12  338749                            Swastik Dhaba     --  Too Few Ratings
# 13  156601                         Jodhpuri Kachori     --  Too Few Ratings
# 14  156587                        Bharawan Da Dhaba    4.4      50+ ratings
# 15  158192                          Tandoori Nights     --  Too Few Ratings
# 16  394554                             Roll Express    4.0      20+ ratings
# 17  158195       wah ji waah veg and non veg corner     --  Too Few Ratings
# 18  257181  Shri Balaji fast food and Variety store     --  Too Few Ratings
# 19  530909                               FOODY MOOD    4.7      20+ ratings
#
#      cost                     cuisine city_names location
# 0   ₹ 200            Beverages,Pizzas     Abohar  General
# 1   ₹ 200               Sweets,Bakery     Abohar  General
# 2   ₹ 100                   Beverages     Abohar  General
# 3   ₹ 250            Fast Food,Indian     Abohar  General
# 4   ₹ 250  Italian-American,Fast Food     Abohar  General
# 5   ₹ 200                 Continental     Abohar  General
# 6   ₹ 150                North Indian     Abohar  General
# 7   ₹ 100                North Indian     Abohar  General
# 8   ₹ 100                Snacks,Chaat     Abohar  General
# 9   ₹ 200                      Indian     Abohar  General
# 10  ₹ 300            Juices,Beverages     Abohar  General
# 11  ₹ 100             Sweets,Desserts     Abohar  General
# 12  ₹ 200                North Indian     Abohar  General
# 13  ₹ 100                      Snacks     Abohar  General
# 14  ₹ 300                      Indian     Abohar  General
# 15  ₹ 300                     Tandoor     Abohar  General
# 16  ₹ 200                   Fast Food     Abohar  General
# 17  ₹ 200        North Indian,Chinese     Abohar  General
# 18  ₹ 100                      Indian     Abohar  General
# 19  ₹ 300           Fast Food,Chinese     Abohar  General

# %%
# Replace '--' with NaN
Swiggy_data['rating'] = Swiggy_data['rating'].replace('--', None)

# Convert to float
Swiggy_data['rating'] = Swiggy_data['rating'].astype(float)

# %%
# Replace 'Too Few Ratings' with 0
Swiggy_data['rating_count'] = Swiggy_data['rating_count'].replace('Too Few Ratings', '0')

# %%
# # Remove '+ ratings' and convert to int
Swiggy_data['rating_count'] = Swiggy_data['rating_count'].str.extract('(\d+)')  # extract numbers only
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipython-input-3750796687.py:2: SyntaxWarning: invalid escape sequence '\d'
#   Swiggy_data['rating_count'] = Swiggy_data['rating_count'].str.extract('(\d+)')  # extract numbers only

# %%
#Convert to integer safely using 'Int64' (Nullable integer type)
Swiggy_data['rating_count'] = Swiggy_data['rating_count'].astype('Int64')

# %%
# remove  ruppe symbol and spaces , convert to number
Swiggy_data['cost'] = Swiggy_data['cost'].str.replace('₹', '').str.strip()
Swiggy_data['cost'] = Swiggy_data['cost'].astype('Int64')

# %%
cuisines = Swiggy_data['cuisine'].dropna().astype(str).str.split(',').sum()

# %%
# strip spaces and get unique set
unique_cuisines = set([c.strip() for c in cuisines])

# %%
Swiggy_data.tail(20)
# Out:
#            id                                       name  rating  \
# 24980  562415                       Anand Sweet & Bakers     NaN
# 24981  551958                             Paratha corner     NaN
# 24982  550575                            The Second Wife     3.5
# 24983  550588             Bombay Sandwich And Pizza Shop     NaN
# 24984  557728                 Brothers Family Restaurant     NaN
# 24985  569766                               Pizza Lovers     NaN
# 24986  567742                       Biryani Shawarma.com     NaN
# 24987  311486                               Rolls Fusion     3.9
# 24988  296025                 Camp Purohit Sweets - Camp     4.2
# 24989  328703                           Kareem s Kitchen     4.0
# 24990  101493                  China Rocks - RPD College     3.9
# 24991  101980                          Hotel New Welcome     3.8
# 24992  503766                           M.K Swamy & Sons     3.3
# 24993  101930                       YoYo Cafe By Saffron     3.8
# 24994  101164                                      Zaika     3.8
# 24995  101824              BBC Bakery & Cafe - Tilakwadi     3.3
# 24996  537377  Hotel Navaratna Palace Bar and Restaurant     NaN
# 24997  148385                          Hotel Panchamruth     3.8
# 24998  133257                               Pizza Corner     4.1
# 24999  438113                                Hotel Milan     NaN
#
#        rating_count  cost                    cuisine       city_names location
# 24980             0   200            Bakery,Desserts  Bela-pratapgarh  General
# 24981             0   200               North Indian  Bela-pratapgarh  General
# 24982            20   200       North Indian,Chinese  Bela-pratapgarh  General
# 24983             0   200           Fast Food,Pizzas  Bela-pratapgarh  General
# 24984             0   200       North Indian,Chinese  Bela-pratapgarh  General
# 24985             0   200             Pizzas,Chinese  Bela-pratapgarh  General
# 24986             0   200           Biryani,Lebanese  Bela-pratapgarh  General
# 24987            20   100      Beverages,Continental          Belgaum  General
# 24988           100   100                     Sweets          Belgaum  General
# 24989           500   250             Biryani,Indian          Belgaum  General
# 24990            20   200                    Chinese          Belgaum  General
# 24991           100   300  North Indian,South Indian          Belgaum  General
# 24992            20   250              Bakery,Pizzas          Belgaum  General
# 24993            20   500       North Indian,Italian          Belgaum  General
# 24994           100   500       North Indian,Chinese          Belgaum  General
# 24995           500   150                   Desserts          Belgaum  General
# 24996             0   300             Chinese,Indian          Belgaum  General
# 24997           100   270  South Indian,North Indian          Belgaum  General
# 24998           100   200                    Italian          Belgaum  General
# 24999             0   250       South Indian,Chinese          Belgaum  General

# %%
Swiggy_data.isnull().sum()
# Out:
# id                  0
# name                0
# rating          13950
# rating_count        0
# cost               12
# cuisine             0
# city_names          0
# location            0
# dtype: int64

# %%
Swiggy_data = Swiggy_data.dropna(subset=['rating'])

# %%
Swiggy_data['cost'] = Swiggy_data['cost'].fillna(Swiggy_data['cost'].median())

# %%
Swiggy_data.isnull().sum()
# Out:
# id              0
# name            0
# rating          0
# rating_count    0
# cost            0
# cuisine         0
# city_names      0
# location        0
# dtype: int64

# %%
Swiggy_data.head()
# Out:
#        id               name  rating  rating_count  cost           cuisine  \
# 1  531342  Janta Sweet House     4.4            50   200     Sweets,Bakery
# 2  158203  theka coffee desi     3.8           100   100         Beverages
# 3  187912          Singh Hut     3.7            20   250  Fast Food,Indian
# 5  158204          Sam Uncle     3.6            20   200       Continental
# 6  156588   shere punjab veg     4.0           100   150      North Indian
#
#   city_names location
# 1     Abohar  General
# 2     Abohar  General
# 3     Abohar  General
# 5     Abohar  General
# 6     Abohar  General

# %%
#Save the cleaned file
Swiggy_data.to_csv("Swiggy_cleaned_data.csv", index=False)

# %%
Swiggy_cleaned_data = pd.read_csv("/content/Swiggy_cleaned_data.csv")

# %%
Swiggy_cleaned_data.head()
# Out:
#        id               name  rating  rating_count  cost           cuisine  \
# 0  531342  Janta Sweet House     4.4            50   200     Sweets,Bakery
# 1  158203  theka coffee desi     3.8           100   100         Beverages
# 2  187912          Singh Hut     3.7            20   250  Fast Food,Indian
# 3  158204          Sam Uncle     3.6            20   200       Continental
# 4  156588   shere punjab veg     4.0           100   150      North Indian
#
#   city_names location
# 0     Abohar  General
# 1     Abohar  General
# 2     Abohar  General
# 3     Abohar  General
# 4     Abohar  General

# %%
# Select categorical columns
categorical_cols = ['name', 'city_names', 'location', 'cuisine']

# %%
## Initialize encoder (note: use sparse_output=False for newer scikit-learn)
encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
encoded_array = encoder.fit_transform(Swiggy_cleaned_data[categorical_cols])

# %%
# Convert to DataFrame
Swiggy_encoded = pd.DataFrame(encoded_array, columns=encoder.get_feature_names_out(categorical_cols))

# %%
# Combine with numerical features
numerical_data = Swiggy_cleaned_data[['rating', 'rating_count', 'cost']].reset_index(drop=True)
final_encoded = pd.concat([numerical_data, Swiggy_encoded], axis=1)

# %%
#save to CSv
final_encoded.to_csv("encoded_data.csv", index=False)

# %%
# Save encoder and encoded data
with open('encoder.pkl', 'wb') as f:
    pickle.dump(encoder, f)

final_encoded.to_csv("encoded_data.csv", index=False)
